# %% [markdown]
# <a href="https://colab.research.google.com/github/karishmashaik549/FMML2024/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 06:49:14--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  87.2MB/s    in 0.8s
#
# 2025-03-16 06:49:15 (87.2 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 35132  cs/9809121v1  We consider information retrieval when the dat...    cs
# 27611  1704.00570v3  Our experiment adapts several popular deep lea...    cs
# 21614   1111.6233v1  Gaussian process models -also called Kriging m...  stat
# 16588  1704.04259v1  In this paper we describe a method to detect e...    cs
# 10615  1604.02123v1  This work is motivated by the needs of predict...  stat
# ...             ...                                                ...   ...
# 5501    1205.2171v2  We study the problem of structured output lear...  stat
# 30808  1801.04662v1  Arithmetic encoding is an essential class of c...    cs
# 25791  1511.06830v2  Base-detail separation is a fundamental comput...    cs
# 396    1707.03374v1  Imitation learning is an effective approach fo...    cs
# 15514  1508.01718v1  In this paper, we have analyzed the impact of ...    cs
#
#                                                    title  year  \
# 35132  Using Local Optimality Criteria for Efficient ...  1998
# 27611  Spatiotemporal Networks for Video Emotion Reco...  2017
# 21614  Additive Covariance Kernels for High-Dimension...  2011
# 16588         Identity and Granularity of Events in Text  2017
# 10615  Multilevel Weighted Support Vector Machine for...  2016
# ...                                                  ...   ...
# 5501   A Generalized Kernel Approach to Structured Ou...  2012
# 30808  Efficient Trimmed Convolutional Arithmetic Enc...  2018
# 25791  Ground-truth dataset and baseline evaluations ...  2015
# 396    Imitation from Observation: Learning to Imitat...  2017
# 15514  Study of Phonemes Confusions in Hierarchical A...  2015
#
#                                                 keywords
# 35132  [information, retrieval, multimedia, coputatio...
# 27611  [experiment, traditional, recognition, experim...
# 21614  [mathematical, approximations, expensive, expe...
# 16588  [different, semantics, components, representat...
# 10615  [motivated, predictive, analytics, healthcare,...
# ...                                                  ...
# 5501   [structured, regression, perspective, formulat...
# 30808  [arithmetic, essential, techniques, compressio...
# 25791  [separation, fundamental, consisting, structur...
# 396    [imitation, effective, autonomous, unavailable...
# 15514  [confusions, robustness, recognitions, confusi...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 35132    [information, retrieval, multimedia, coputatio...
# 27611    [experiment, traditional, recognition, experim...
# 21614    [mathematical, approximations, expensive, expe...
# 16588    [different, semantics, components, representat...
# 10615    [motivated, predictive, analytics, healthcare,...
#                                ...
# 22819    [technologies, opportunities, resolution, moni...
# 21731    [unsupervised, exploratory, inference, restric...
# 34975    [electronics, transistors, according, classica...
# 32831    [constrained, algorithms, orthogonal, algorith...
# 10489    [classical, multidimensional, distances, dimen...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8764 words.
# Out of those 4538 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8efbdbbf-c4a4-40d4-b1db-56da020a15d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8efbdbbf-c4a4-40d4-b1db-56da020a15d4")) {                    Plotly.newPlot(                        "8efbdbbf-c4a4-40d4-b1db-56da020a15d4",                        [{"x":["sufficient","understanding","optimality","retrieval","information","redundant","especially","polynomial","execution","algorithm","solutions","concurrency","multimedia","necessity","efficient","applications","processing","parallelism","interested","bottleneck","concurrent","implemented","exponential","considerably","important","experimentally","expensive","processor","application","characteristic","suboptimal","multimodal","architecture","traditional","classification","extraction","spatiotemporal","experiment","recognition","properties","approximations","classical","increases","unrealistic","dimensionality","experiments","observation","resulting","covariance","dimensional","mathematical","dimension","simplified","granularity","interconnected","descriptions","semantics","coreference","demonstrate","outperforming","components","detection","differences","representations","different","approaches","relations","framework","predictive","electronic","performance","techniques","development","healthcare","imbalanced","multilevel","regression","imputation","imbalance","analytics","problematic","maximization","motivated","algorithms","invariably","represented","specialized","simultaneously","sensitive","benchmark","interests","preprocessing","predictions","connections","backpropagation","artificial","successfully","distinguished","knowledge","benchmarks","automatically","constructive","extensive","involving","attributes","effectiveness","discarded","generalization","determined","irrelevant","interpretable","desirable","eliminate","generally","experimental","identification","leveraging","sequences","markovian","unsupervised","distributions","dependencies","embedding","inference","realistic","transitions","prediction","stochastic","introduce","variational","nonlinear","intractable","significantly","assumptions","including","constraint","correlated","discovering","constraints","intelligent","clustering","comparative","applicability","statistical","implementations","preference","variations","operations","methodologies","registration","investigation","parameters","uncertainty","available","evaluation","entropies","reference","thresholding","availability","maximisation","suitability","addressed","reconstruction","generalized","methodology","implications","denoising","posteriors","posterior","optimizing","algorithmic","attempted","deconvolution","tomographic","compressive","maximizing","similarities","distribution","approximated","approximate","trajectories","resolution","unrelated","resonance","optimization","acquisition","conducting","contradictions","simulations","understood","underlying","federated","verification","epistemology","hypotheses","introduction","addresses","hypothesis","developing","computable"],"y":[57,139,25,108,687,24,116,56,30,775,153,3,16,13,397,442,292,10,24,19,9,83,48,27,354,51,60,10,257,27,15,38,237,185,481,122,14,82,347,240,26,107,50,5,43,591,54,143,19,156,58,68,20,10,3,44,117,8,533,31,106,363,45,229,749,442,82,535,53,24,872,391,132,11,9,3,114,4,8,8,5,34,60,607,1,89,26,104,52,219,15,25,74,50,16,137,90,6,348,76,186,6,197,44,62,206,4,129,45,12,16,22,14,77,380,98,46,112,6,152,116,54,91,200,68,8,229,117,365,55,61,28,275,66,281,72,32,27,166,62,142,29,39,152,43,29,73,85,14,21,38,259,80,300,281,4,52,17,31,1,10,48,112,82,66,28,27,3,41,47,37,6,10,2,12,33,40,204,14,117,37,107,4,15,342,28,7,2,35,20,138,4,34,2,26,39,60,49,60,16],"type":"bar"},{"x":["sufficient","understandi ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4538,), (4538, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7908333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.7241379310344827);'>Categorization</span> <span style=''>with</span> <span style=''>Sparse</span> <span style=''>Fisher</span> <span style=''>Vector</span> <br/><br/><span style=''>In</span> <span style=''>object</span> <span style='background-color:rgba(0, 255, 0, 0.6139534883720931);'>recognition</span> <span style=''>Fisher</span> <span style=''>vector</span> <span style=''>(FV)</span> <span style='background-color:rgba(0, 255, 0, 0.36622390891840606);'>representation</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>art</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3753753753753754);'>representations</span> <span style=''>ways</span> <span style=''>at</span> <span style=''>the</span> <span style=''>expense</span> <span style=''>of</span> <span style=''>dense</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.41463414634146334);'>dimensional</span> <span style=''>features</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3650793650793651);'>increased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>time</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>simplification</span> <span style=''>of</span> <span style=''>FV</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>attractive</span> <span style=''>so</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>Sparse</span> <span style=''>Fisher</span> <span style=''>vector</span> <span style=''>(SFV)</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporating</span> <span style=''>locality</span> <span style=''>strategy</span> <span style=''>we</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerate</span> <span style=''>the</span> <span style=''>Fisher</span> <span style=''>coding</span> <span style=''>step</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7241379310344827);'>categorization</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.360655737704918);'>implemented</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.375);'>collective</span> <span style=''>of</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.6818181818181819);'>descriptors</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Combining</span> <span style=''>with</span> <span style=''>pooling</span> <span style=''>step</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>between</span> <span style=''>coding</span> <span style=''>step</span> <span style=''>and</span> <span style=''>pooling</span> <span style=''>step</span> <span style=''>to</span> <span style=''>give</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</span> <span style=''>about</span> <span style=''>SFV</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experiments</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3074626865671642);'>benchmark</span> <span style=''>datasets</span> <span style=''>have</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>SFV</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</ ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Review</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <span style=''>in</span> <span style=''>HMRF</span> <br/><br/><span style=''>This</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technical</span> <span style=''>report</span> <span style=''>which</span> <span style=''>explores</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodologies</span> <span style=''>on</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>in</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>and</span> <span style=''>Gaussian</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>In</span> <span style=''>first</span> <span style=''>section</span> <span style=''>we</span> <span style=''>briefly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Metropolis</span> <span style=''>Hastings</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>Next</span> <span style=''>by</span> <span style=''>using</span> <span style=''>MH</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>we</span> <span style=''>simulate</span> <span style=''>the</span> <span style=''>data</span> <span style=''>from</span> <span style=''>Ising</span> <span style=''>model</span> <span style=''>and</span> <span style=''>study</span> <span style=''>on</span> <span style=''>how</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>Ising</span> <span style=''>model</span> <span style=''>is</span> <span style=''>enabled</span> <span style=''>through</span> <span style=''>MCMC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>using</span> <span style=''>pseudo</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Following</span> <span style=''>section</span> <span style=''>deals</span> <span style=''>with</span> <span style=''>an</span> <span style=''>issue</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>process</span> <span style=''>of</span> <span style=''>Gaussian</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Random</span> <span style=''>Field</span> <span style=''>using</span> <span style=''>MAP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>EM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discusses</span> <span style=''>problems</span> <span style=''>found</span> <span style=''>through</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>sectio ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Data</span> <span style=''>Driven</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Threshold</span> <span style=''>Machine</span> <span style=''>Scan</span> <span style='background-color:rgba(255, 0, 0, 0.3567251461988305);'>Statistics</span> <span style=''>Change</span> <span style=''>Point</span> <span style='background-color:rgba(0, 255, 0, 0.5188284518828452);'>Detection</span> <span style=''>and</span> <span style=''>Extreme</span> <span style=''>Bandits</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>free</span> <span style=''>approach</span> <span style=''>the</span> <span style=''>data</span> <span style=''>driven</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>threshold</span> <span style=''>machine</span> <span style=''>(DTM)</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>fundamental</span> <span style=''>problem</span> <span style=''>at</span> <span style=''>the</span> <span style=''>core</span> <span style=''>of</span> <span style=''>many</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>choose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>threshold</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>pre</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>specified</span> <span style=''>level</span> <span style=''>that</span> <span style=''>bounds</span> <span style=''>the</span> <span style=''>tail</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>maximum</span> <span style=''>of</span> <span style=''>a</span> <span style=''>(possibly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>but</span> <span style=''>stationary)</span> <span style=''>random</span> <span style=''>sequence</span> <span style=''>We</span> <span style=''>do</span> <span style=''>not</span> <span style=''>assume</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>but</span> <span style=''>rather</span> <span style=''>relying</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5535714285714286);'>asymptotic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>extremal</span> <span style=''>values</span> <span style=''>and</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>three</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>the</span> <span style=''>extreme</span> <span style=''>value</span> <span style='background-color:rgba(255, 0, 0, 0.350140056022409);'>distributions</span> <span style=''>and</span> <span style=''>the</span> <span style=''>extremal</span> <span style=''>index</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>specially</span> <span style=''>take</span> <span style=''>care</span> <span style=''>of</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependence</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.36216216216216224);'>estimating</span> <span style=''>extremal</span> <span style=''>index</span> <span style=''>since</span> <span style=''>in</span> <span style=''>many</span> <span style=''>settings</span> <span style=''>such</span> <span style=''>as</span> <span style=''>scan</span> <span style='background-color:rgba(25 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Divide</span> <span style=''>and</span> <span style=''>Conquer</span> <span style=''>Learning</span> <span style=''>by</span> <span style=''>Anchoring</span> <span style=''>a</span> <span style=''>Conical</span> <span style=''>Hull</span> <br/><br/><span style=''>We</span> <span style=''>reduce</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>class</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>usually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>by</span> <span style=''>EM</span> <span style=''>or</span> <span style=''>sampling</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>finding</span> <span style=''>the</span> <span style=''>k</span> <span style=''>extremal</span> <span style=''>rays</span> <span style=''>spanning</span> <span style=''>the</span> <span style=''>conical</span> <span style=''>hull</span> <span style=''>of</span> <span style=''>a</span> <span style=''>data</span> <span style=''>point</span> <span style=''>set</span> <span style=''>These</span> <span style=''>k</span> <span style=''>anchors</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>a</span> <span style=''>global</span> <span style=''>solution</span> <span style=''>and</span> <span style=''>a</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretable</span> <span style=''>model</span> <span style=''>that</span> <span style=''>can</span> <span style=''>even</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperform</span> <span style=''>EM</span> <span style=''>and</span> <span style=''>sampling</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>To</span> <span style=''>find</span> <span style=''>the</span> <span style=''>k</span> <span style=''>anchors</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>divide</span> <span style=''>and</span> <span style=''>conquer</span> <span style=''>learning</span> <span style=''>scheme</span> <span style=''>DCA</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributes</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>to</span> <span style=''>mathcal</span> <span style=''>O(klog</span> <span style=''>k)</span> <span style=''>same</span> <span style=''>type</span> <span style=''>sub</span> <span style=''>problems</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>low</span> <span style=''>D</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hyperplanes</span> <span style=''>each</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>by</span> <span style=''>any</span> <span style=''>solver</span> <span style=''>For</span> <span style=''>the</span> <span style=''>2D</span> <span style=''>sub</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style=''>solver</span> <span style=''>that</span> <span style=''>only</span> <span style=''>needs</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>an</span> <span style=''>array</span> <span style=''>of</span> <span style=''>cosine</span> <span style=''>values</span> <span style=''>and</span> <span style=''>its</span> <span style=''>maxmin</span> <span style=''>entries</span> <span style=''>DCA</span> <span style=''>also</span> <span style=''>provides</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1238875044499822)
# 	processing (0.10395158419366322)
# 	evaluation (0.10003559985760056)
# 	architecture (0.08437166251334995)
# 	segmentation (0.06835172659309363)
# 	information (0.24457102171591313)
# 	different (0.2666429334282663)
# 	detection (0.12922748309006765)
# 	recognition (0.1235315058739765)
# 	convolutional (0.13670345318618726)
#
# Some Statistics words are:
# 	theoretical (0.14565544952285284)
# 	variables (0.1411351079859367)
# 	stochastic (0.13460572576594676)
# 	estimation (0.16122551481667505)
# 	statistical (0.15770969362129583)
# 	algorithm (0.3847312908086389)
# 	distribution (0.18483174284279258)
# 	inference (0.20140632847815168)
# 	dimensional (0.18935208437970869)
# 	regression (0.18232044198895028)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="956c3a6d-4b79-44f9-83a2-5a4bac60fe5f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("956c3a6d-4b79-44f9-83a2-5a4bac60fe5f")) {                    Plotly.newPlot(                        "956c3a6d-4b79-44f9-83a2-5a4bac60fe5f",                        [{"x":["sufficient","understanding","optimality","retrieval","information","redundant","especially","polynomial","execution","algorithm","solutions","concurrency","multimedia","necessity","efficient","applications","processing","parallelism","interested","bottleneck","concurrent","implemented","exponential","considerably","important","experimentally","expensive","processor","application","characteristic","suboptimal","multimodal","architecture","traditional","classification","extraction","spatiotemporal","experiment","recognition","properties","approximations","classical","increases","unrealistic","dimensionality","experiments","observation","resulting","covariance","dimensional","mathematical","dimension","simplified","granularity","interconnected","descriptions","semantics","coreference","demonstrate","outperforming","components","detection","differences","representations","different","approaches","relations","framework","predictive","electronic","performance","techniques","development","healthcare","imbalanced","multilevel","regression","imputation","imbalance","analytics","problematic","maximization","motivated","algorithms","invariably","represented","specialized","simultaneously","sensitive","benchmark","interests","preprocessing","predictions","connections","backpropagation","artificial","successfully","distinguished","knowledge","benchmarks","automatically","constructive","extensive","involving","attributes","effectiveness","discarded","generalization","determined","irrelevant","interpretable","desirable","eliminate","generally","experimental","identification","leveraging","sequences","markovian","unsupervised","distributions","dependencies","embedding","inference","realistic","transitions","prediction","stochastic","introduce","variational","nonlinear","intractable","significantly","assumptions","including","constraint","correlated","discovering","constraints","intelligent","clustering","comparative","applicability","statistical","implementations","preference","variations","operations","methodologies","registration","investigation","parameters","uncertainty","available","evaluation","entropies","reference","thresholding","availability","maximisation","suitability","addressed","reconstruction","generalized","methodology","implications","denoising","posteriors","posterior","optimizing","algorithmic","attempted","deconvolution","tomographic","compressive","maximizing","similarities","distribution","approximated","approximate","trajectories","resolution","unrelated","resonance","optimization","acquisition","conducting","contradictions","simulations","understood","underlying","federated","verification","epistemology","hypotheses","introduction","addresses","hypothesis","developing","computable","philosophy","furthermore","simulation","mathematics","challenges","composing","executable","validation","addressing","particular","potential","questions","reinforcement","targeting","university","effectively","translation","translate","adaptation","selection","submitted","annotated","therefore","improvements","alleviate","ontonotes","generating","exploiting","mechanism","comprehension","outperforms","equilibrium","relatively","generative","adversarial","diversity","resolutions","procedure","wasserstein","enforcing","milestone","generator","additionally","discriminator","controlling","generation","convergence","abstractions","developed","rendering","attribution","challenging","ext ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	covariates
# 	econometric
# 	stepsizes
# 	framelets
# 	epidemics
# 	infectious
# 	oscillates
# 	similitude
# 	thetastar
# 	rewritten
# 	conjugacy
# 	readmission
# 	ancestral
# 	factorizes
# 	staleness
# 	autocorrelation
# 	replicates
# 	meteorological
# 	precipitation
# 	blockmodel
# Some words which never appear in Statistics papers:
# 	concurrency
# 	coreference
# 	discarded
# 	contradictions
# 	federated
# 	epistemology
# 	milestone
# 	abstractions
# 	attribution
# 	allegedly
# 	operatively
# 	anthropomorphic
# 	listening
# 	addiction
# 	functionally
# 	judgement
# 	homography
# 	underwater
# 	eligibility
# 	linearisation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0648522741203875e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.745
